# %% [markdown]
# # Pandas - Charts & Graphs

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(np.random.randn(25) , columns = ["Data"] , index = pd.date_range('2023/01/01' , periods = 25))

# %%
df
# Out:
#                 Data
# 2023-01-01  1.078831
# 2023-01-02  0.782574
# 2023-01-03 -0.180815
# 2023-01-04 -1.154033
# 2023-01-05 -0.646997
# 2023-01-06  0.509273
# 2023-01-07  0.188190
# 2023-01-08 -0.553274
# 2023-01-09  0.696274
# 2023-01-10 -1.175214
# 2023-01-11 -1.098386
# 2023-01-12 -0.146448
# 2023-01-13  0.227863
# 2023-01-14 -1.327675
# 2023-01-15 -0.980016
# 2023-01-16 -1.705546
# 2023-01-17 -0.865162
# 2023-01-18 -1.029968
# 2023-01-19  1.174665
# 2023-01-20  0.765547
# 2023-01-21  0.328979
# 2023-01-22  0.308596
# 2023-01-23  0.055586
# 2023-01-24  0.981630
# 2023-01-25  0.620933

# %%
df.plot(figsize = (20,10))
# Out:
# <Axes: >

# %%
df1 = pd.read_csv("https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv")

# %% [markdown]
# #

# %%
df1
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df1.plot(figsize = (21,11))
# Out:
# <Axes: >

# %%
df1.plot(kind='bar' , figsize=(20,10))
# Out:
# <Axes: >

# %%
df1.plot(kind='kde' , figsize=(20,10))
# Out:
# <Axes: ylabel='Density'>

# %%
df1.iloc[5:10].plot(kind='bar' , figsize=(20,10))
# Out:
# <Axes: >

# %%
df1.iloc[5:10].plot(kind='barh' , figsize=(20,10))
# Out:
# <Axes: >

# %%
df1.plot(kind='hist',figsize=(20,10))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df1
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df1['petal.length'].plot(kind='hist',color = '#e6ccff')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Data'}>]], dtype=object)

# %%
df1.hist(color = "g",alpha=0.4)

#alpha is used to define the color intensity
# Out:
# array([[<Axes: title={'center': 'sepal.length'}>,
#         <Axes: title={'center': 'sepal.width'}>],
#        [<Axes: title={'center': 'petal.length'}>,
#         <Axes: title={'center': 'petal.width'}>]], dtype=object)

# %%
df1
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df1.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df1.plot(kind='box' , figsize=(20,10),color={'boxes':"r","whiskers":"g"})
# Out:
# <Axes: >

# %%
df1.plot(kind='box' , figsize=(20,10),vert=False)
# Out:
# <Axes: >

# %%
df1.plot(kind='area')
# Out:
# <Axes: >

# %%
df1.plot(kind='area' , stacked=False)
# Out:
# <Axes: >

# %%
df1.plot.scatter(x='sepal.length',y='petal.length')
# Out:
# <Axes: xlabel='sepal.length', ylabel='petal.length'>

# %%
df1.plot.scatter(x='sepal.length',y='petal.length' , c = 'sepal.width',figsize=(20,10),s=150)
# Out:
# <Axes: xlabel='sepal.length', ylabel='petal.length'>

# %%
df1.plot.scatter(x='sepal.length',y='petal.length' , c = 'sepal.width',figsize=(20,10), s = df1['petal.length']*200)
# Out:
# <Axes: xlabel='sepal.length', ylabel='petal.length'>

# %%
df1.plot.hexbin(x = ['petal.length'] , y = ['sepal.length'] , gridsize=10)
# Out:
# <Axes: xlabel='[petal.length]', ylabel='[sepal.length]'>

# %%
df2 = df1.drop('variety',axis=1).iloc[0]

# %%
df2
# Out:
# sepal.length    5.1
# sepal.width     3.5
# petal.length    1.4
# petal.width     0.2
# Name: 0, dtype: float64

# %%
df2.plot(kind='pie')
# Out:
# <Axes: ylabel='0'>

# %%
df
# Out:
#                 Data
# 2023-01-01  1.078831
# 2023-01-02  0.782574
# 2023-01-03 -0.180815
# 2023-01-04 -1.154033
# 2023-01-05 -0.646997
# 2023-01-06  0.509273
# 2023-01-07  0.188190
# 2023-01-08 -0.553274
# 2023-01-09  0.696274
# 2023-01-10 -1.175214
# 2023-01-11 -1.098386
# 2023-01-12 -0.146448
# 2023-01-13  0.227863
# 2023-01-14 -1.327675
# 2023-01-15 -0.980016
# 2023-01-16 -1.705546
# 2023-01-17 -0.865162
# 2023-01-18 -1.029968
# 2023-01-19  1.174665
# 2023-01-20  0.765547
# 2023-01-21  0.328979
# 2023-01-22  0.308596
# 2023-01-23  0.055586
# 2023-01-24  0.981630
# 2023-01-25  0.620933

# %%
df1
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df2
# Out:
# sepal.length    5.1
# sepal.width     3.5
# petal.length    1.4
# petal.width     0.2
# Name: 0, dtype: float64

# %% [markdown]
# # PyPlot

# %%
pip install plotly
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cufflinks
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install chart_studio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cufflinks as cf
cf.go_offline()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning:
#
# Blowfish has been deprecated
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df1.iplot()
# Out:
# <div>                            <div id="68698656-9b58-461a-a264-0f9dc035c1ed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.iplot(x = 'sepal.length'  , y = 'petal.length',mode = 'markers', kind = 'scatter')
# Out:
# <div>                            <div id="fcac5f40-f558-49f7-a9ce-0ac877b6cc1e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.iplot(kind = "scatter" , mode = 'markers' , size = 10)
# Out:
# <div>                            <div id="f926bf1e-08e2-4ed2-afeb-fb5749039d94" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.iplot(kind = 'bubble' , x = 'sepal.length' , y = 'petal.length',size = 'sepal.width')
# Out:
# <div>                            <div id="f5d581e2-d798-4f95-8def-7a084778e7b7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.scatter_matrix()
# Out:
# <div>                            <div id="e0da0909-9d98-4042-8534-4f831af98a06" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1.iplot(kind ='scatter3d' , x ='sepal.length' , y ='sepal.width' , z= 'petal.length'  )
# Out:
# <div>                            <div id="25caf768-037c-4a72-9232-70ec909494a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
